# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 

import warnings

# %%
# data import 
df = pd.read_csv('Iris.csv')

df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# 1st 5 row 
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# 3. Display descriptive statistics for the numerical columns  
df.describe
# Out:
# <bound method NDFrame.describe of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
# Display a concise summary of the DataFrame (data types, non-null counts, etc.)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    str
# dtypes: float64(4), int64(1), str(1)
# memory usage: 7.2 KB

# %%
# Display the number of rows and columns(shape)
df.shape
# Out:
# (150, 6)

# %%
# Display the count of each species type(class distribution)
print(df["Species"].value_counts)
print()
print(df["Species"].value_counts())
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: str>
#
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
setosa = df[df["Species"] == "Iris-setosa"]
versicolor = df[df["Species"] == "Iris-versicolor"]
virginica = df[df["Species"] == "Iris-virginica"]

# %%
# Matplotlib for Plots
# _______________________________________________________________________________________________________________
#   #Single line plot
# 1. Plot 'SepalLengthCm' using a red dashed line ('r--')  
# ____________________________________________________________________________________________________________________
#    #Multiline plot 
#    #Drop non-numeric columns like 'Id' and 'Species' for this type of plot  
# 2. Plot all columns as separate lines
# _________________________________________________________________________________________________________________
#   #Generates a scatter plot of Sepal Length vs. Petal Length, differentiating the species by color. 
# 3. Create the scatter plot  
# _____________________________________________________________________________________________________________________
#    #Histogram of a Single Feature  
# 4. plot Histogram of Sepal Width  
# _____________________________________________________________________________________________________________________
#   #Box Plot of All Features 
# 5. plot Box and whisker for each numerical attribute

# %%
plt.plot(df['SepalLengthCm'] , 'r--')
plt.title("Sepal Length in Cm")
plt.xlabel("Index")
plt.ylabel("Sepal length")
plt.show()

# %%
numeric_df = df.drop(columns=["Id" , "Species"])
numeric_df.plot(figsize=(8 , 8))
plt.title("Multiline Plot of Numerical Features")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
# setosa = df[df["Species"] == "Iris-setosa"]
# versicolor = df[df["Species"] == "Iris-versicolor"]
# virginica = df[df["Species"] == "Iris-virginica"]

#  Filter data by species for coloring
plt.scatter(setosa["SepalLengthCm"], setosa["SepalWidthCm"], color="red", label="Setosa")
plt.scatter(versicolor["SepalLengthCm"], versicolor["SepalWidthCm"], color="green", label="Versicolor")
plt.scatter(virginica["SepalLengthCm"], virginica["SepalWidthCm"], color="blue", label="Virginica")

plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend()
plt.show()

# %%
plt.hist(df["SepalWidthCm"] , bins=25, edgecolor="black" , color="skyblue")
plt.title("Histogram of Sepal Width")
plt.xlabel("Sepal Width in CM")
plt.ylabel("Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.boxplot([
    df["SepalWidthCm"],
    df["SepalLengthCm"],
    df["PetalWidthCm"],
    df["PetalLengthCm"]
])

plt.title("Box Plot of Sepal Width and Sepal Length")
plt.xticks([1, 2], ["Sepal Width", "Sepal Length"])
plt.ylabel("Length (cm)")
plt.show()
